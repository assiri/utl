# %% [markdown]
# #### Play the video below to see a walk-through of this module.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('TnKCnetIvDM')

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\python310\lib\site-packages (2.0.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\python310\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\python310\lib\site-packages (from pandas) (1.25.1)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)

# %% [markdown]
# # iakids: Introduction to Jupyter and Python
# ## Part 3
#
# This Jupyter notebook is all about graphing and data.

# %% [markdown]
# ## Graphing
#
# To make graphs, we will use some Python libraries (libraries are code written by other people that you can import and use).

# %%
# import libraries
import matplotlib.pyplot as plt
# %matplotlib inline
print('Successfully imported the matplotlib library.')
# Out:
# Successfully imported the matplotlib library.

# %%
x = [1, 2, 3, 4]
y = [5, 6, 7, 8]

# scatter plot
plt.scatter(x, y)
plt.show()

# %%
# line graph of the same data
plt.plot(x, y)
plt.show()

# %%
# bar graph
labels = ['English', 'French', 'Aboriginal Language', 'Other']
sizes = [56.9, 21.3, 0.6, 21.2]
plt.title('First Languages Spoken in Canada')
plt.bar(labels, sizes)
plt.show()

# %%
# pie chart
labels = ['left-handed', 'right-handed']
sizes = [3, 21]
plt.title('Handedness of People in our Class')
plt.pie(sizes, labels=labels)
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Graphing Online Data
#
# We can use some libraries to graph data from websites, for example [hourly tide data](https://www.waterlevels.gc.ca/eng/station?sid=215).

# %%
# !pip install  requests numpy pandas plotly-express lxml
# Out:
# Requirement already satisfied: requests in c:\python310\lib\site-packages (2.31.0)
# Requirement already satisfied: numpy in c:\python310\lib\site-packages (1.25.1)
# Requirement already satisfied: pandas in c:\python310\lib\site-packages (2.0.3)
# Requirement already satisfied: plotly-express in c:\python310\lib\site-packages (0.4.1)
# Requirement already satisfied: lxml in c:\python310\lib\site-packages (4.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python310\lib\site-packages (from requests) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\python310\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python310\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python310\lib\site-packages (from requests) (2022.12.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\python310\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\python310\lib\site-packages (from plotly-express) (0.14.0)
# Requirement already satisfied: plotly>=4.1.0 in c:\python310\lib\site-packages (from plotly-express) (5.15.0)
# Requirement already satisfied: scipy>=0.18 in c:\python310\lib\site-packages (from plotly-express) (1.11.1)
# Requirement already satisfied: patsy>=0.5 in c:\python310\lib\site-packages (from plotly-express) (0.5.3)
# Requirement already satisfied: six in c:\python310\lib\site-packages (from patsy>=0.5->plotly-express) (1.16.0)
# Requirement already satisfied: packaging in c:\python310\lib\site-packages (from plotly>=4.1.0->plotly-express) (23.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\python310\lib\site-packages (from plotly>=4.1.0->plotly-express) (8.2.2)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)

# %%
import requests
import pandas as pd
import plotly.express as px
print('Libraries imported')
# Out:
# Libraries imported

# %%
# Get tide data from Fisheries and Oceans Canada for Joggins Wharf (hourly for the next 7 days)
url = 'https://www.waterlevels.gc.ca/eng/station?sid=215'
response = requests.get(url)

dfs = pd.read_html(response.text) # construct dataframe
tideHeight = dfs[7]['Hour'].transpose() # select the 7th frame and transpose columns and rows

tideList = [] # construct a list from the tideHeight data
for key in tideHeight.keys():
    tideList.extend(tideHeight[key].tolist())

df = pd.DataFrame(tideList) # turn the list into a dataframe
df.columns = ['Height (m)'] # label the height column
df['Time (h)'] = range(0,len(tideList)) # add a time (in hours) column

fig = px.line(df, x='Time (h)', y='Height (m)', title='Joggins Wharf Tide Data') # create graph
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python310\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File C:\Python310\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Python310\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Hour'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 6
#       3 response = requests.get(url)
#       5 dfs = pd.read_html(response.text) # construct dataframe
# ----> 6 tideHeight = dfs[7]['Hour'].transpose() # select the 7th frame and transpose columns and rows
#       8 tideList = [] # construct a list from the tideHeight data
#       9 for key in tideHeight.keys():
#
# File C:\Python310\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File C:\Python310\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Hour'
